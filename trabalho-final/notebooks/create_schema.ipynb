# %%
# %sql
create catalog if not exists mongo_db;
create schema if not exists mongo_db.bronze;
create schema if not exists mongo_db.landing;
create volume if not exists mongo_db.landing.sample_mflix;
create schema if not exists mongo_db.silver;
